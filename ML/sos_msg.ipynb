# %%
from twilio.rest import Client
import random



account_sid = 'AC4c79210f299290a7a53e8c749be5e7b6'
auth_token = 'ba43bbfa079450b0a291cbeb07d14897'
client = Client(account_sid, auth_token)

message = client.messages.create(

  body=f'Hello' ,
  from_='+18153840986',
  to='+918766049932'
)
