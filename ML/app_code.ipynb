# %%
os.environ["PINECONE_API_KEY"] = "pcsk_5jDCsX_USAvwQuMsXnPEu1PjymLpzkFzheMBupvnbQiqXMdSVWXXXFYY21uzzvucBSUovD"
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
print(PINECONE_API_KEY)  # Ensure it's set correctly

# %%
# Load Existing index

from langchain_pinecone import PineconeVectorStore

# Embed each chunk and upsert the embeddings into your Pinecone index.
docsearch = PineconeVectorStore.from_existing_index(
    index_name="medbot",
    embedding=embeddings,
)

# %%
retriever = docsearch.as_retriever(search_type="similarity", search_kwargs={"k": 3})

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-4o-mini", temperature=0.4, max_tokens=100)

# %%
system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use three sentences maximum and keep the "
    "answer concise."
    "\n\n"
    "{context}"
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system",system_prompt),
        ("human","{input}"),
    ]
)

# %%
question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response = rag_chain.invoke({"input": "MY knee is paining a lot"})
print(response["answer"])
